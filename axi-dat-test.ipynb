# %%
# plotting .dat files from running .ini files from AxiCLASS

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# cl lensed from explanatory ini

ell = np.loadtxt("explanatory01_cl_lensed.dat",usecols=0)
clTT = np.loadtxt("explanatory01_cl_lensed.dat",usecols=1)

plt.xscale('log')
plt.xlabel(r'$\ell$')
plt.ylabel("TT")
plt.plot(ell, clTT)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# matter power spectrum from best fit parameters ini

k = np.loadtxt("best_fit_paper_z0_pk.dat",usecols=0)
P = np.loadtxt("best_fit_paper_z0_pk.dat",usecols=1)

plt.xscale('log')
plt.yscale('log')
plt.xlabel("k")
plt.ylabel("P")
plt.plot(k, P)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# plotted using data from example_axiCLASS.ini

ell = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/axion_n3_phi2n_v2_cl.dat",usecols=0)
clTT = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/axion_n3_phi2n_v2_cl.dat",usecols=1)

plt.xscale('log')
plt.xlabel(r'$\ell$')
plt.ylabel("TT")
plt.plot(ell, clTT)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# plotted using data from pheno_axion_transition_tests.ini

k = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/w_cs2_n_2pk.dat",usecols=0)
P = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/w_cs2_n_2pk.dat",usecols=1)

plt.xscale('log')
plt.yscale('log')
plt.xlabel("k")
plt.ylabel("P")
plt.plot(k, P)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# plotted using data from example_axiCLASS.ini

ell_l = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/w_cs2_n_2cl_lensed.dat",usecols=0)
clTT_l = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/w_cs2_n_2cl_lensed.dat",usecols=1)

ell = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/w_cs2_n_2cl.dat",usecols=0)
clTT = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/w_cs2_n_2cl.dat",usecols=1)


fig, axs = plt.subplots(2)

axs[0].set_xscale("log")
#axs[0].set_ylim(0,8)
axs[0].plot(ell_l, clTT_l)

axs[1].set_xscale("log")
#axs[1].set_ylim(0,8)
axs[1].plot(ell, clTT)


# plt.xscale('log')
# plt.xlabel(r'$\ell$')
# plt.ylabel("TT")
# plt.plot(ell_l, clTT_l)
# plt.show

# plt.xscale('log')
# plt.xlabel(r'$\ell$')
# plt.ylabel("TT")
# plt.plot(ell, clTT)
# plt.show

# %%
# plotted using data from example_axiCLASS.ini

ell = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/w_cs2_n_2cl.dat",usecols=0)
clTT = np.loadtxt("/Users/brendazhou/Cosmo/Repositories/AxiCLASS/output/w_cs2_n_2cl.dat",usecols=1)

plt.xscale('log')
plt.xlabel(r'$\ell$')
plt.ylabel("TT")
plt.plot(ell, clTT)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
