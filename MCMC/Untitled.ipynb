# %%
from cobaya.yaml import yaml_load_file

info_from_yaml = yaml_load_file("log10ac_v2.yaml")

from cobaya.run import run

updated_info, sampler = run(info_from_yaml)
# Out:
# [run] Input info updated with defaults (dumped to YAML):
# theory:
#   classy:
#     path: /Users/brendazhou/Cosmo/Repositories/AxiCLASS/
#     speed: 0.2
#     stop_at_error: true
#     extra_args:
#       non linear: hmcode
#       hmcode_min_k_max: 20
#       N_ncdm: 1
#       N_ur: 2.0328
#     use_renames: false
#     renames:
#       As: A_s
#       ns: n_s
#       nrun: alpha_s
#       nrunrun: beta_s
#       nt: n_t
#       ntrun: alpha_t
#       rdrag: rs_drag
#       omegak: Omega_k
#       omegal: Omega_Lambda
#       w: w0_fld
#       wa: wa_fld
#       omegabh2: omega_b
#       omegab: Omega_b
#       omegach2: omega_cdm
#       omegac: Omega_cdm
#       omegam: Omega_m
#       omegan: Omega_nu
#       tau: tau_reio
#       zrei: z_reio
#       deltazrei: reionization_width
#       helium_redshift: helium_fullreio_redshift
#       helium_delta_redshift: helium_fullreio_width
#       yhe: YHe
#       yheused: YHe
#     version: null
# likelihood:
#   planck_2018_lowl.TT:
#     path: null
#     clik_file: baseline/plc_3.0/low_l/commander/commander_dx12_v3_2_29.clik
#     product_id: '151902'
#     aliases:
#     - lowl
#     speed: 3000
#     params:
#       A_planck:
#         prior:
#           dist: norm
#           loc: 1
#           scale: 0.0025
#         ref:
#           dist: norm
#           loc: 1
#           scale: 0.002
#         proposal: 0.0005
#         latex: y_\mathrm{cal}
#         renames: calPlanck
#     type: CMB
#     stop_at_error: false
#     version: null
#   planck_2018_lowl.EE:
#     path: null
#     clik_file: baseline/plc_3.0/low_l/simall/simall_100x143_offlike5_EE_Aplanck_B.clik
#     product_id: '151902'
#     aliases:
#     - lowE
#     speed: 4000
#     params:
#       A_planck:
#         prior:
#           dist: norm
#           loc: 1
#           scale: 0.0025
#         ref:
#           dist: norm
#           loc: 1
#           scale: 0.002
#         proposal: 0.0005
#         latex: y_\mathrm{cal}
#         renames: calPlanck
#     type: CMB
#     stop_at_error: false
#     version: null
#   planck_2018_lensing.clik:
#     path: null
#     clik_file: baseline/plc_3.0/lensing/smicadx12_Dec5_ftl_mv2_ndclpp_p_teb_consext8.clik_lensing
#     product_id: '151902'
#     aliases:
#     - lensing
#     speed: 600
#     params:
#       A_planck:
#         prior:
#           dist: norm
#           loc: 1
#           scale: 0.0025
#         ref:
#           dist: norm
#           loc: 1
#           scale: 0.002
#         proposal: 0.0005
#         latex: y_\mathrm{cal}
#         renames: calPlanck
#     type: CMB
#     stop_at_error: false
#     version: null
# params:
#   n_axion:
#     value: 2
#   log10_axion_ac:
#     prior:
#       min: -4.4
#       max: -3.6
#     ref:
#       dist: norm
#       loc: -4.13
#       scale: 0.1
#   log10_fraction_axion_ac:
#     prior:
#       min: -3
#       max: 3
#     ref:
#       min: -2
#       max: 2
#   logA:
#     prior:
#       min: 1.61
#       max: 3.91
#     ref:
#       dist: norm
#       loc: 3.05
#       scale: 0.001
#     proposal: 0.001
#     latex: \log(10^{10} A_\mathrm{s})
#     drop: true
#   A_s:
#     value: 'lambda logA: 1e-10*np.exp(logA)'
#     latex: A_\mathrm{s}
#     derived: true
#     renames:
#     - As
#   n_s:
#     prior:
#       min: 0.8
#       max: 1.2
#     ref:
#       dist: norm
#       loc: 0.965
#       scale: 0.004
#     proposal: 0.002
#     latex: n_\mathrm{s}
#     renames:
#     - ns
#   theta_s_1e2:
#     prior:
#       min: 0.5
#       max: 10
#     ref:
#       dist: norm
#       loc: 1.0416
#       scale: 0.0004
#     proposal: 0.0002
#     latex: 100\theta_\mathrm{s}
#     drop: true
#   100*theta_s:
#     value: 'lambda theta_s_1e2: theta_s_1e2'
#     derived: false
#   H0:
#     latex: H_0
#     derived: true
#   omega_b:
#     prior:
#       min: 0.005
#       max: 0.1
#     ref:
#       dist: norm
#       loc: 0.0224
#       scale: 0.0001
#     proposal: 0.0001
#     latex: \Omega_\mathrm{b} h^2
#     renames:
#     - omegabh2
#   omega_cdm:
#     prior:
#       min: 0.001
#       max: 0.99
#     ref:
#       dist: norm
#       loc: 0.12
#       scale: 0.001
#     proposal: 0.0005
#     latex: \Omega_\mathrm{c} h^2
#     renames:
#     - omegach2
#   Omega_m:
#     latex: \Omega_\mathrm{m}
#     derived: true
#     renames:
#     - omegam
#   omegamh2:
#     derived: 'lambda Omega_m, H0: Omega_m*(H0/100)**2'
#     latex: \Omega_\mathrm{m} h^2
#   m_ncdm:
#     value: 0.06
#     renames: mnu
#   Omega_Lambda:
#     latex: \Omega_\Lambda
#     derived: true
#     renames:
#     - omegal
#   YHe:
#     latex: Y_\mathrm{P}
#     derived: true
#     renames:
#     - yhe
#     - yheused
#   tau_reio:
#     prior:
#       min: 0.01
#       max: 0.8
#     ref:
#       dist: norm
#       loc: 0.055
#       scale: 0.006
#     proposal: 0.003
#     latex: \tau_\mathrm{reio}
#     renames:
#     - tau
#   z_reio:
#     latex: z_\mathrm{re}
#     derived: true
#     renames:
#     - zrei
#   sigma8:
#     latex: \sigma_8
#     derived: true
#   s8h5:
#     derived: 'lambda sigma8, H0: sigma8*(H0*1e-2)**(-0.5)'
#     latex: \sigma_8/h^{0.5}
#   s8omegamp5:
#     derived: 'lambda sigma8, Omega_m: sigma8*Omega_m**0.5'
#     latex: \sigma_8 \Omega_\mathrm{m}^{0.5}
#   s8omegamp25:
#     derived: 'lambda sigma8, Omega_m: sigma8*Omega_m**0.25'
#     latex: \sigma_8 \Omega_\mathrm{m}^{0.25}
#   A:
#     derived: 'lambda A_s: 1e9*A_s'
#     latex: 10^9 A_\mathrm{s}
#   clamp:
#     derived: 'lambda A_s, tau_reio: 1e9*A_s*np.exp(-2*tau_reio)'
#     latex: 10^9 A_\mathrm{s} e^{-2\tau}
#   age:
#     latex: '{\rm{Age}}/\mathrm{Gyr}'
#     derived: true
#   rs_drag:
#     latex: r_\mathrm{drag}
#     derived: true
#     renames:
#     - rdrag
#   scf_tuning_index:
#     value: 0
#   scf_parameters:
#     value: 10000
#   A_planck:
#     prior:
#       dist: norm
#       loc: 1
#       scale: 0.0025
#     ref:
#       dist: norm
#       loc: 1
#       scale: 0.002
#     proposal: 0.0005
#     latex: y_\mathrm{cal}
#     renames: calPlanck
#   chi2__CMB:
#     latex: \chi^2_\mathrm{CMB}
#     derived: true
# sampler:
#   evaluate:
#     N: 1
#     override: null
#     seed: null
#     version: null
# debug: true
#
# [classy] Importing *local* classy from /Users/brendazhou/Cosmo/Repositories/AxiCLASS/
# [evaluate] Initialized!
# [evaluate] Looking for a reference point with non-zero prior.
# [evaluate] Reference point:
#    log10_axion_ac = -4.29576
#    log10_fraction_axion_ac = 0.56932
#    logA = 3.0482
#    n_s = 0.963711
#    theta_s_1e2 = 1.04137
#    omega_b = 0.0225023
#    omega_cdm = 0.120577
#    tau_reio = 0.0563718
#    A_planck = 1.00112
# [evaluate] Evaluating prior and likelihoods...
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -4.295755797894113, 'log10_fraction_axion_ac': 0.5693196886645526, 'A_s': 2.1077424452898445e-09, 'n_s': 0.9637106389492508, '100*theta_s': 1.041372546072395, 'omega_b': 0.022502300034212767, 'omega_cdm': 0.12057726767293649, 'm_ncdm': 0.06, 'tau_reio': 0.05637184992956402, 'scf_tuning_index': 0, 'scf_parameters': 10000} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl mPk', 'lensing': 'yes', 'l_max_scalars': 2500, 'P_k_max_1/Mpc': 1}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Error at evaluation: CosmoSevereError('Class did not read input parameter(s): n_axion\n')
# ---------------------------------------------------------------------------
# CosmoSevereError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/cobaya/theory.py in check_cache_and_compute(self, dependency_params, want_derived, cached, **params_values_dict)
#     247             try:
# --> 248                 if self.calculate(state, want_derived, **params_values_dict) is False:
#     249                     return False
#
# ~/.local/lib/python3.8/site-packages/cobaya/theories/classy/classy.py in calculate(self, state, want_derived, **params_values_dict)
#     351         try:
# --> 352             self.classy.compute()
#     353         # "Valid" failure of CLASS: parameters too extreme -> log and report
#
# classy.pyx in classy.Class.compute()
#
# CosmoSevereError:
#
# Error in Class: Class did not read input parameter(s): n_axion
#
#
# During handling of the above exception, another exception occurred:
#
# LoggedError                               Traceback (most recent call last)
# <ipython-input-18-270caa382bf5> in <module>
#       5 from cobaya.run import run
#       6
# ----> 7 updated_info, sampler = run(info_from_yaml)
#
# ~/.local/lib/python3.8/site-packages/cobaya/run.py in run(info)
#      99             return updated_info, sampler
#     100         # Run the sampler
# --> 101         sampler.run()
#     102     return updated_info, sampler
#     103
#
# ~/.local/lib/python3.8/site-packages/cobaya/sampler.py in run(self)
#     268         """
#     269         self._set_rng()
# --> 270         self._run()
#     271         self._release_rng()
#     272
#
# ~/.local/lib/python3.8/site-packages/cobaya/samplers/evaluate/evaluate.py in _run(self)
#      62                 ["%s = %g" % pv for pv in reference_point.items()]))
#      63             self.log.info("Evaluating prior and likelihoods...")
# ---> 64             self.logposterior = self.model.logposterior(reference_point)
#      65             self.one_point.add(
#      66                 list(reference_point.values()), derived=self.logposterior.derived,
#
# ~/.local/lib/python3.8/site-packages/cobaya/model.py in logposterior(self, params_values, return_derived, make_finite, cached)
#     398         logpost = sum(logpriors)
#     399         if -np.inf not in logpriors:
# --> 400             like = self.loglikes(params_values, return_derived=return_derived,
#     401                                  make_finite=make_finite, cached=cached, _no_check=True)
#     402             loglikes, derived_sampler = like if return_derived else (like, [])
#
# ~/.local/lib/python3.8/site-packages/cobaya/model.py in loglikes(self, params_values, return_derived, make_finite, cached, _no_check)
#     304         input_params = self.parameterization.to_input(params_values, copied=False)
#     305
# --> 306         result = self.logps(input_params, return_derived=return_derived,
#     307                             cached=cached, make_finite=make_finite)
#     308         if return_derived:
#
# ~/.local/lib/python3.8/site-packages/cobaya/model.py in logps(self, input_params, return_derived, cached, make_finite)
#     236                 [input_params[p] for p in param_dep]
#     237             params = {p: input_params[p] for p in component.input_params}
# --> 238             compute_success = component.check_cache_and_compute(
#     239                 want_derived=return_derived,
#     240                 dependency_params=depend_list,
#
# ~/.local/lib/python3.8/site-packages/cobaya/theory.py in check_cache_and_compute(self, dependency_params, want_derived, cached, **params_values_dict)
#     252             except Exception as e:
#     253                 if self.stop_at_error:
# --> 254                     raise LoggedError(self.log, "Error at evaluation: %r", e)
#     255                 else:
#     256                     self.log.debug(
#
# LoggedError: Error at evaluation: CosmoSevereError('Class did not read input parameter(s): n_axion\n')

# %%
import clik
