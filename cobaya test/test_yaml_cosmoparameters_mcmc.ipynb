# %%
from cobaya.yaml import yaml_load_file

info_from_yaml = yaml_load_file("varying_v2.yaml")

# %%
from cobaya.run import run

sampler = run(info_from_yaml)
# Out:
# [prior] *WARNING* External prior 'SZ' loaded. Mind that it might not be normalized!
# [classy] Importing *local* classy from /Users/brendazhou/Cosmo/Repositories/AxiCLASS/
# [bao.sixdf_2011_bao] Initialising.
# [bao.sdss_dr7_mgs] Initialising.
# [bao.sdss_dr12_consensus_bao] Initialising.
# [mcmc] Getting initial point... (this may take a few seconds)
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.942510596511769, 'log10_fraction_axion_ac': -1.8152808554163413, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.5101182565875195, 'log10_fraction_axion_ac': -0.7715054693701089, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.792992316704303, 'log10_fraction_axion_ac': -0.9247773255444627, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.663404358752847, 'log10_fraction_axion_ac': -1.7396260588588524, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.82634469569777, 'log10_fraction_axion_ac': 1.8351824560650902, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.5003246352185267, 'log10_fraction_axion_ac': -1.615629156059296, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.5254870958653597, 'log10_fraction_axion_ac': 1.1703436074025197, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.829833999579531, 'log10_fraction_axion_ac': 0.03864571802034167, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.880784346247681, 'log10_fraction_axion_ac': -0.0015879958243991688, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.89617240495899, 'log10_fraction_axion_ac': 0.22781030374256206, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.5464280310444805, 'log10_fraction_axion_ac': -1.962806695766512, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.887318825670045, 'log10_fraction_axion_ac': -1.9684784655566796, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.655229701129107, 'log10_fraction_axion_ac': 0.4204196897264829, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.6147929916180326, 'log10_fraction_axion_ac': 1.5839767397069346, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.975090906549203, 'log10_fraction_axion_ac': 0.16804117806877716, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.861275301419122, 'log10_fraction_axion_ac': 0.6422500621894689, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.8383246927906756, 'log10_fraction_axion_ac': -0.7703258324394304, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.7121777055835627, 'log10_fraction_axion_ac': -1.8049035193812135, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.636377230521724, 'log10_fraction_axion_ac': -0.48302457435673807, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.7722530555828655, 'log10_fraction_axion_ac': 1.501400970891817, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.621569498613545, 'log10_fraction_axion_ac': 0.5313208415969091, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.8056821629511246, 'log10_fraction_axion_ac': 0.5564277857555515, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.6332486806178688, 'log10_fraction_axion_ac': -1.4801099628938177, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.9395394653254954, 'log10_fraction_axion_ac': -0.6532484273848422, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.5775280756925585, 'log10_fraction_axion_ac': -0.6063066693969139, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.811159780702053, 'log10_fraction_axion_ac': 0.9637391286477115, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.834282640059174, 'log10_fraction_axion_ac': -1.1026090347087822, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.6740068720732215, 'log10_fraction_axion_ac': -1.1694072777624744, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.9246554742862636, 'log10_fraction_axion_ac': 1.1176859986464716, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.601096100923137, 'log10_fraction_axion_ac': 0.9764472553866845, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.862594642501268, 'log10_fraction_axion_ac': 0.07912935643437446, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.9140023274312337, 'log10_fraction_axion_ac': 1.5765097849299132, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.8089248197652874, 'log10_fraction_axion_ac': -0.3725090620580582, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.6235575533139333, 'log10_fraction_axion_ac': -1.5728768818390546, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.727138227165084, 'log10_fraction_axion_ac': -1.3589428975566062, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.6944942387630095, 'log10_fraction_axion_ac': -1.2469382872245882, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.744967214060379, 'log10_fraction_axion_ac': 0.8450384238811393, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.6541839185955296, 'log10_fraction_axion_ac': 0.08709596636150119, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.5004029577437437, 'log10_fraction_axion_ac': 1.154297662053803, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [classy] *ERROR* Serious error setting parameters or computing results. The parameters passed were {'n_axion': 2, 'log10_axion_ac': -2.728394415740569, 'log10_fraction_axion_ac': -1.086350220623808, 'A_s': 2.23e-09, 'n_s': 0.9828, 'omega_b': 0.02228, 'omega_cdm': 0.1281, 'tau_reio': 0.083} and {'non linear': 'hmcode', 'hmcode_min_k_max': 20, 'N_ncdm': 1, 'N_ur': 2.0328, 'output': 'tCl pCl lCl', 'lensing': 'yes', 'l_max_scalars': 2508}. See original CLASS's error traceback below.
#
# [model] *ERROR* Could not find random point giving finite likelihood after 920 tries
# ---------------------------------------------------------------------------
# LoggedError                               Traceback (most recent call last)
# <ipython-input-11-4e2e729e55b2> in <module>
#       1 from cobaya.run import run
#       2
# ----> 3 sampler = run(info_from_yaml)
#
# ~/.local/lib/python3.8/site-packages/cobaya/run.py in run(info)
#      85         updated_info = recursive_update(updated_info, model.info())
#      86         output.check_and_dump_info(None, updated_info, check_compatible=False)
# ---> 87         sampler = sampler_class(updated_info[kinds.sampler][sampler_name],
#      88                                 model, output, packages_path=info.get(_packages_path))
#      89         # Re-dump updated info, now also containing updates from the sampler
#
# ~/.local/lib/python3.8/site-packages/cobaya/sampler.py in __init__(self, info_sampler, model, output, packages_path, name)
#     255                 pass
#     256         self._set_rng()
# --> 257         self.initialize()
#     258         self._release_rng()
#     259         self.model.set_cache_size(self._get_requested_cache_size())
#
# ~/.local/lib/python3.8/site-packages/cobaya/samplers/mcmc/mcmc.py in initialize(self)
#     150             self.log.info("Getting initial point... (this may take a few seconds)")
#     151             initial_point, logpost, logpriors, loglikes, derived = \
# --> 152                 self.model.get_valid_point(max_tries=self.max_tries.value)
#     153             # If resuming but no existing chain, assume failed run and ignore blocking
#     154             # if speeds measurement requested
#
# ~/.local/lib/python3.8/site-packages/cobaya/model.py in get_valid_point(self, max_tries, ignore_fixed_ref)
#     452                 raise LoggedError(self.log, "The reference point provided has null "
#     453                                   "likelihood. Set 'ref' to a different point or a pdf.")
# --> 454             raise LoggedError(self.log, "Could not find random point giving finite "
#     455                                         "likelihood after %g tries", max_tries)
#     456         return initial_point, logpost, logpriors, loglikes, derived
#
# LoggedError: Could not find random point giving finite likelihood after 920 tries

# %%
# Export the results to GetDist
from getdist.mcsamples import MCSamplesFromCobaya

gd_sample = MCSamplesFromCobaya(updated_info, sampler.products()["sample"])
# Analyze and plot
mean = gd_sample.getMeans()[:2]
covmat = gd_sample.getCovMat().matrix[:2, :2]
print("Mean:")
print(mean)
print("Covariance matrix:")
print(covmat)
# %matplotlib inline  
# uncomment if running from the Jupyter notebook
import getdist.plots as gdplt

gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot(gd_sample, ["a", "b"], filled=True)
